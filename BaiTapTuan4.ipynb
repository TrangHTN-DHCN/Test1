# %% [markdown]
# CHo một số nguyên dương (int), tìm số đảo ngược của nó
# Chỉ xử lý dữ liệu kiểu số nguyên
# 12345689786756 ->???

# %%
n = int(input())
if (n > 0):
    n_rev = 0
    while n > 0:
        print(n)
        n_rev = n_rev *10 + n%10
        n //= 10
        
    print(n_rev)
else: 
    print("KHong xu ly so am")

# %%
n = int(input())

if (n > 0):
    n_rev = 0
    for _ in range(1000000):
        if (n == 0):
            break
        n_rev = n_rev*10 + n%10
        n //= 10
    print(n_rev)
else:
    print("Khong xu ly so nho hon bang KHONG")

# %% [markdown]
# Nhap mot so nguyen N cho den khi duoc mot so NGUYEN DUONG thi thoi
# Kiem tra xem N co phai la so nguyen to khong (chi chia het cho 1 va chinh no - so 2
# la so nguyen to nho nhat)

# %%
while True:
    n = int(input())
    if(n > 0):
        break

for i in range(2, int(n**0.5) + 1):
    if n%i == 0:
        print(f"{n} la hop so")
        break
else:
    print(f"{n} la so nguyen to")



# cnt = 1
# for i in range(2, n+1):
#     if n%i == 0:
#         cnt += 1

# if(cnt == 2):
#     print(f"{n} la so nguyen to")
# else:
#     print(f"{n} la hop so")
# Out:
# 25 la so nguyen to
# 25 la so nguyen to
# 25 la so nguyen to
# 25 la hop so
